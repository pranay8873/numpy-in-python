# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 30]

plt.plot(x, y)
plt

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)

# %%
plt.bar(x,y)

# %%
plot=plt.bar(x,y)
plt.xlabel("x-axis")
plt.ylabel("Y-axis")

# %%
plot
