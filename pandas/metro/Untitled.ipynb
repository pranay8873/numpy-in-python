# %%
import pandas as pd
metro_incidents=pd.read_csv("metro_incidents.csv")
metro_incidents

# %%
metro_stations=pd.read_csv("metro_stations.csv")
metro_stations

# %%
metro_trains=pd.read_csv("metro_trains.csv")
metro_trains

# %%
metro_trips=pd.read_csv("metro_trips.csv")
metro_trips

# %%
metro_trips.info()

# %%
metro_trips[metro_trips.isna()]

# %%
metro_incidents.info()

# %%
metro_incidents["Incident_Date"]=pd.to_datetime(metro_incidents["Incident_Date"])

# %%
metro_incidents.info()

# %%
metro_incidents.describe()
